# %% [markdown]
# # Ejercicio de Fundamentos: Clasificando estrellas
#
# Ahora te toca resolver un problema con menos instrucciones.
#
# Trabajaremos con un pequeño dataset **simulado con fines educativos** inspirado en propiedades estelares.
#
# > Los valores no representan un catálogo astronómico real.
#
# La pregunta es:
#
# > **¿Podemos utilizar temperatura, luminosidad y radio para distinguir dos grupos de estrellas?**
#
# ## Cómo usar este notebook
#
# 1. intenta cada ejercicio;
# 2. abre **Pista** si te atascas;
# 3. abre **Solución** solamente después de intentarlo.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
stars = pd.DataFrame({
    "temperature_K": [3200, 3500, 3900, 4300, 4700, 5200, 5700, 6100, 6900, 7600, 8500, 9800],
    "luminosity_solar": [0.08, 0.12, 0.20, 0.35, 0.55, 0.85, 1.00, 1.4, 2.5, 4.1, 7.0, 12.0],
    "radius_solar": [0.45, 0.50, 0.58, 0.66, 0.75, 0.88, 1.00, 1.08, 1.25, 1.45, 1.70, 2.10],
    "group": ["cool"]*6 + ["hot"]*6
})

stars

# %% [markdown]
# ## Ejercicio 1 — Identifica `X` e `y`
#
# Queremos predecir `group`.
#
# Usa como features:
#
# - `temperature_K`
# - `luminosity_solar`
# - `radius_solar`

# %%
# Escribe tu solución aquí

# X = ...
# y = ...

# %% [markdown]
# <details>
# <summary><strong>Pista</strong></summary>
#
# Para seleccionar varias columnas:
#
# ```python
# df[["columna_1", "columna_2"]]
# ```
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# X = stars[["temperature_K", "luminosity_solar", "radius_solar"]]
# y = stars["group"]
# ```
#
# </details>

# %% [markdown]
# ## Ejercicio 2 — Interpreta el shape
#
# Imprime `X.shape` y `y.shape`.
#
# Después responde:
#
# - ¿cuántos samples?
# - ¿cuántas features?
# - ¿cuántas labels?

# %%
# Tu código aquí

# %% [markdown]
# <details>
# <summary><strong>Pista</strong></summary>
#
# ```text
# X.shape = (n_samples, n_features)
# ```
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# print(X.shape)
# print(y.shape)
# ```
#
# Resultado:
#
# ```text
# (12, 3)
# (12,)
# ```
#
# </details>

# %% [markdown]
# ## Ejercicio 3 — Visualiza una feature
#
# Haz un histograma de `temperature_K` con título y nombres de ejes.

# %%
# Tu código aquí

# %% [markdown]
# <details>
# <summary><strong>Pista</strong></summary>
#
# Comienza con:
#
# ```python
# plt.hist(stars["temperature_K"])
# ```
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# plt.figure(figsize=(7, 4))
# plt.hist(stars["temperature_K"], bins=8, edgecolor="black")
# plt.xlabel("Temperatura (K)")
# plt.ylabel("Número de estrellas")
# plt.title("Distribución de temperatura")
# plt.show()
# ```
#
# </details>

# %% [markdown]
# ## Ejercicio 4 — Busca un patrón entre dos features
#
# Haz un scatter plot de:
#
# - `temperature_K`
# - `luminosity_solar`
#
# y separa visualmente los grupos `cool` y `hot`.

# %%
# Tu código aquí

# %% [markdown]
# <details>
# <summary><strong>Pista</strong></summary>
#
# Crea máscaras:
#
# ```python
# cool = stars["group"] == "cool"
# hot = stars["group"] == "hot"
# ```
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# cool = stars["group"] == "cool"
# hot = stars["group"] == "hot"
#
# plt.figure(figsize=(7, 5))
# plt.scatter(stars.loc[cool, "temperature_K"],
#             stars.loc[cool, "luminosity_solar"],
#             label="cool")
#
# plt.scatter(stars.loc[hot, "temperature_K"],
#             stars.loc[hot, "luminosity_solar"],
#             label="hot")
#
# plt.xlabel("Temperatura (K)")
# plt.ylabel("Luminosidad (L☉)")
# plt.title("Temperatura vs. luminosidad")
# plt.legend()
# plt.show()
# ```
#
# </details>

# %% [markdown]
# ## Ejercicio 5 — Construye una regla manual
#
# Encuentra un threshold de temperatura para separar `cool` y `hot`.
#
# Completa:
#
# ```python
# threshold = ...
# prediction = stars["temperature_K"] > threshold
# truth = stars["group"] == "hot"
# accuracy = ...
# ```

# %%
# Tu código aquí

# %% [markdown]
# <details>
# <summary><strong>Pista</strong></summary>
#
# Inspecciona:
#
# ```python
# stars.groupby("group")["temperature_K"].agg(["min", "max"])
# ```
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# Una posible solución:
#
# ```python
# threshold = 5450
#
# prediction = stars["temperature_K"] > threshold
# truth = stars["group"] == "hot"
#
# accuracy = (prediction == truth).mean()
# print("Accuracy:", accuracy)
# ```
#
# En este dataset educativo la separación es deliberadamente sencilla.
#
# </details>

# %% [markdown]
# ## Ejercicio 6 — Conecta la regla con una neurona
#
# Una neurona sencilla calcula:
#
# \[
# z=wx+b
# \]
#
# Si usamos \(w=1\), ¿qué valor de \(b\) hace que \(z=0\) cuando \(x=\text{threshold}\)?

# %%
# Tu código aquí

# w = 1.0
# b = ...
# x = ...
# z = ...

# %% [markdown]
# <details>
# <summary><strong>Pista</strong></summary>
#
# Si:
#
# \[
# 0=w(\text{threshold})+b
# \]
#
# despeja \(b\).
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# \[
# b=-\text{threshold}
# \]
#
# Por ejemplo:
#
# ```python
# threshold = 5450
# w = 1.0
# b = -threshold
#
# x = 6000
# z = w*x + b
#
# print(z)
# ```
#
# </details>

# %% [markdown]
# # Desafío final
#
# ¿Qué ocurriría si:
#
# - las dos clases se solaparan;
# - las mediciones tuvieran incertidumbre;
# - una sola feature no fuera suficiente;
# - existieran tres o más clases?
#
# <details>
# <summary><strong>Pista</strong></summary>
#
# Piensa en por qué necesitaríamos múltiples features y una frontera más flexible.
#
# </details>
#
# <details>
# <summary><strong>Mostrar una posible respuesta</strong></summary>
#
# Una regla manual con un solo threshold dejaría de ser suficiente.
#
# Necesitaríamos combinar varias features y aprender una frontera de decisión más flexible.
#
# Eso es precisamente lo que comenzaremos a hacer con **redes neuronales**.
#
# </details>

# %% [markdown]
# # Para llevar al salón de clases
#
# Este tipo de ejercicio puede adaptarse a:
#
# | Área | Features | Posible label |
# |---|---|---|
# | Botánica | largo, ancho, área de una hoja | especie |
# | Meteorología | temperatura, humedad, presión | lluvia / no lluvia |
# | Astronomía | temperatura, luminosidad, color | tipo de estrella |
# | Ecología | variables del suelo y clima | tipo de hábitat |
# | Física | mediciones experimentales | clase de evento |
#
# La pregunta central es:
#
# > **¿Qué mediciones permitirían a una computadora distinguir diferentes fenómenos científicos?**
