# %% [markdown]
# # Ejercicio Integrador — Tu Primera Red Neuronal Completa
#
# En esta actividad construirás, entrenarás y evaluarás una red neuronal con PyTorch.
#
# Aplicarás:
#
# - preparación de datos;
# - train/test split;
# - estandarización;
# - tensors;
# - arquitectura;
# - forward pass;
# - loss;
# - optimizer;
# - training loop;
# - accuracy;
# - confusion matrix;
# - análisis de predicciones.
#
# Trabajaremos con un problema científico de clasificación usando el dataset **Wine** de Scikit-learn.
#
# El dataset contiene mediciones químicas de diferentes muestras de vino.
#
# No utilizaremos este ejemplo como un problema comercial.
#
# Lo trataremos como un conjunto de **mediciones químicas multivariadas** para practicar clasificación científica.
#
# ## Instrucciones
#
# Intenta cada parte antes de abrir la pista.
#
# Utiliza la solución solamente después de haber trabajado el problema.

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report

import torch
import torch.nn as nn

# %% [markdown]
# ## Parte 1 — Explora el dataset
#
# Carga el dataset Wine y determina:
#
# - número de samples;
# - número de features;
# - número de clases.
#
# ### Tu código

# %%
# wine = ...
# X = ...
# y = ...

# %% [markdown]
# <details>
# <summary><strong>Pista</strong></summary>
#
# Usa:
#
# ```python
# from sklearn.datasets import load_wine
# ```
#
# y después:
#
# ```python
# wine = load_wine()
# ```
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# wine = load_wine()
#
# X = wine.data
# y = wine.target
#
# print("X.shape =", X.shape)
# print("y.shape =", y.shape)
# print("Classes =", wine.target_names)
# ```
#
# </details>

# %% [markdown]
# ## Parte 2 — Identifica algunas features
#
# Imprime los nombres de las variables medidas.
#
# ### Tu código

# %%
# Tu código aquí

# %% [markdown]
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# for feature in wine.feature_names:
#     print(feature)
# ```
#
# Estas son mediciones químicas o propiedades derivadas de las muestras.
#
# </details>

# %% [markdown]
# ## Parte 3 — Training y test sets
#
# Divide:
#
# ```text
# 80% training
# 20% test
# ```
#
# Usa:
#
# ```python
# random_state=42
# stratify=y
# ```
#
# ### Tu código

# %%
# Tu código aquí

# %% [markdown]
# <details>
# <summary><strong>Pista</strong></summary>
#
# Utiliza `train_test_split`.
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# X_train, X_test, y_train, y_test = train_test_split(
#     X,
#     y,
#     test_size=0.20,
#     random_state=42,
#     stratify=y
# )
# ```
#
# </details>

# %% [markdown]
# ## Parte 4 — Estandariza las features
#
# Completa:
#
# ```python
# scaler = ...
#
# X_train_scaled = ...
# X_test_scaled = ...
# ```
#
# Recuerda que solo debes ajustar el scaler con training data.

# %%
# Tu código aquí

# %% [markdown]
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# scaler = StandardScaler()
#
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.transform(X_test)
# ```
#
# </details>

# %% [markdown]
# ## Parte 5 — Convierte a tensors
#
# Crea:
#
# - `X_train_t`
# - `X_test_t`
# - `y_train_t`
# - `y_test_t`
#
# ### Tu código

# %%
# Tu código aquí

# %% [markdown]
# <details>
# <summary><strong>Pista</strong></summary>
#
# Features:
#
# ```python
# dtype=torch.float32
# ```
#
# Labels para CrossEntropy:
#
# ```python
# dtype=torch.long
# ```
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# X_train_t = torch.tensor(X_train_scaled, dtype=torch.float32)
# X_test_t = torch.tensor(X_test_scaled, dtype=torch.float32)
#
# y_train_t = torch.tensor(y_train, dtype=torch.long)
# y_test_t = torch.tensor(y_test, dtype=torch.long)
# ```
#
# </details>

# %% [markdown]
# ## Parte 6 — Diseña la arquitectura
#
# Determina primero:
#
# ```text
# n_inputs  = número de features
# n_outputs = número de clases
# ```
#
# Construye una red:
#
# ```text
# n_inputs → 16 → 8 → n_outputs
# ```
#
# con ReLU entre las hidden layers.
#
# ### Tu código

# %%
# model = nn.Sequential(
#     ...
# )

# %% [markdown]
# <details>
# <summary><strong>Pista</strong></summary>
#
# El dataset Wine tiene 13 features y 3 clases.
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# model = nn.Sequential(
#     nn.Linear(13, 16),
#     nn.ReLU(),
#     nn.Linear(16, 8),
#     nn.ReLU(),
#     nn.Linear(8, 3)
# )
# ```
#
# </details>

# %% [markdown]
# ## Parte 7 — Cuenta los parámetros
#
# Calcula manualmente primero.
#
# Arquitectura:
#
# ```text
# 13 → 16 → 8 → 3
# ```
#
# Después verifica con PyTorch.
#
# ### Tu código

# %%
# total_params = ...

# %% [markdown]
# <details>
# <summary><strong>Pista</strong></summary>
#
# Usa:
#
# \[
# n_\text{in}n_\text{out}+n_\text{out}
# \]
#
# para cada capa.
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# Primera capa:
#
# \[
# 13\times16+16=224
# \]
#
# Segunda:
#
# \[
# 16\times8+8=136
# \]
#
# Tercera:
#
# \[
# 8\times3+3=27
# \]
#
# Total:
#
# \[
# 224+136+27=387.
# \]
#
# Verificación:
#
# ```python
# total_params = sum(p.numel() for p in model.parameters())
# print(total_params)
# ```
#
# </details>

# %% [markdown]
# ## Parte 8 — Loss y optimizer
#
# Usa:
#
# ```python
# nn.CrossEntropyLoss()
# ```
#
# y SGD con:
#
# ```text
# learning rate = 0.05
# ```
#
# ### Tu código

# %%
# criterion = ...
# optimizer = ...

# %% [markdown]
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# criterion = nn.CrossEntropyLoss()
#
# optimizer = torch.optim.SGD(
#     model.parameters(),
#     lr=0.05
# )
# ```
#
# </details>

# %% [markdown]
# ## Parte 9 — Training loop
#
# Entrena durante:
#
# ```text
# 300 epochs
# ```
#
# Guarda la loss en:
#
# ```python
# loss_history
# ```
#
# ### Tu código

# %%
epochs = 300
loss_history = []

# completa aquí

# %% [markdown]
# <details>
# <summary><strong>Pista</strong></summary>
#
# Cada epoch necesita:
#
# ```text
# forward
# loss
# zero_grad
# backward
# step
# ```
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# epochs = 300
# loss_history = []
#
# for epoch in range(epochs):
#
#     logits = model(X_train_t)
#
#     loss = criterion(logits, y_train_t)
#
#     optimizer.zero_grad()
#     loss.backward()
#     optimizer.step()
#
#     loss_history.append(loss.item())
# ```
#
# </details>

# %% [markdown]
# ## Parte 10 — Visualiza la training loss
#
# ### Tu código

# %%
# Tu código aquí

# %% [markdown]
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# plt.figure(figsize=(7, 4))
# plt.plot(loss_history)
# plt.xlabel("Epoch")
# plt.ylabel("Loss")
# plt.title("Training Loss")
# plt.show()
# ```
#
# </details>

# %% [markdown]
# ## Parte 11 — Evalúa training y test accuracy
#
# Completa una función:
#
# ```python
# def accuracy(model, X, y):
#     ...
# ```

# %%
def accuracy(model, X, y):
    # completa aquí
    pass

# %% [markdown]
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# def accuracy(model, X, y):
#
#     with torch.no_grad():
#         logits = model(X)
#         predictions = torch.argmax(logits, dim=1)
#
#     return (predictions == y).float().mean().item()
# ```
#
# </details>

# %%
# Después de completar accuracy():

# print("Train accuracy:", accuracy(model, X_train_t, y_train_t))
# print("Test accuracy: ", accuracy(model, X_test_t, y_test_t))

# %% [markdown]
# ## Parte 12 — Confusion Matrix
#
# Calcula las predicciones del test set y construye la confusion matrix.

# %%
# Tu código aquí

# %% [markdown]
# <details>
# <summary><strong>Pista</strong></summary>
#
# Primero:
#
# ```python
# with torch.no_grad():
#     test_logits = model(X_test_t)
#     test_pred = torch.argmax(test_logits, dim=1)
# ```
#
# Después usa `confusion_matrix`.
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# with torch.no_grad():
#
#     test_logits = model(X_test_t)
#     test_pred = torch.argmax(test_logits, dim=1)
#
# cm = confusion_matrix(
#     y_test_t.numpy(),
#     test_pred.numpy()
# )
#
# print(cm)
# ```
#
# </details>

# %% [markdown]
# ## Parte 13 — Visualiza la confusion matrix
#
# ### Tu código

# %%
# Tu código aquí

# %% [markdown]
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# plt.figure(figsize=(6, 5))
# plt.imshow(cm)
#
# plt.xticks(range(3), wine.target_names)
# plt.yticks(range(3), wine.target_names)
#
# plt.xlabel("Predicted class")
# plt.ylabel("True class")
# plt.title("Confusion Matrix")
#
# for i in range(cm.shape[0]):
#     for j in range(cm.shape[1]):
#         plt.text(j, i, cm[i, j], ha="center", va="center")
#
# plt.colorbar()
# plt.show()
# ```
#
# </details>

# %% [markdown]
# ## Parte 14 — Classification report
#
# Obtén:
#
# - precision;
# - recall;
# - F1-score.
#
# ### Tu código

# %%
# Tu código aquí

# %% [markdown]
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# print(
#     classification_report(
#         y_test_t.numpy(),
#         test_pred.numpy(),
#         target_names=wine.target_names
#     )
# )
# ```
#
# </details>

# %% [markdown]
# # Desafío final 1 — Cambia la arquitectura
#
# Compara:
#
# ```text
# 13 → 8 → 3
# ```
#
# con:
#
# ```text
# 13 → 32 → 16 → 3
# ```
#
# Preguntas:
#
# 1. ¿Cuál tiene más parámetros?
# 2. ¿Cuál entrena más rápido?
# 3. ¿Cuál obtiene mejor test accuracy?
# 4. ¿Una red más grande siempre mejora el resultado?
#
# <details>
# <summary><strong>Mostrar respuesta conceptual</strong></summary>
#
# Una red más grande tiene mayor capacidad, pero eso no garantiza mejor generalización.
#
# Puede:
#
# - aprender mejor;
# - entrenar más lentamente;
# - sobreajustar;
# - o simplemente añadir complejidad innecesaria.
#
# La arquitectura debe evaluarse experimentalmente.
#
# </details>

# %% [markdown]
# # Desafío final 2 — Interpreta el experimento
#
# Responde con tus propias palabras:
#
# 1. ¿Qué fueron las features?
# 2. ¿Qué aprendió realmente la red?
# 3. ¿Qué función tuvo la loss?
# 4. ¿Qué hizo `loss.backward()`?
# 5. ¿Qué hizo `optimizer.step()`?
# 6. ¿Por qué necesitamos un test set?
#
# <details>
# <summary><strong>Mostrar una posible respuesta</strong></summary>
#
# - Las features fueron las mediciones químicas.
# - La red aprendió weights y biases.
# - La loss cuantificó el error.
# - `loss.backward()` calculó los gradientes.
# - `optimizer.step()` actualizó los parámetros.
# - El test set permitió evaluar generalización a datos no usados para entrenar.
#
# </details>

# %% [markdown]
# # Checklist
#
# Al completar este ejercicio deberías poder construir por tu cuenta:
#
# ```text
# dataset
#    ↓
# train/test split
#    ↓
# preprocessing
#    ↓
# tensors
#    ↓
# network
#    ↓
# loss + optimizer
#    ↓
# training loop
#    ↓
# evaluation
# ```
#
# Este es el flujo básico de un proyecto de Deep Learning.
#
# A partir de aquí podemos comenzar a estudiar redes **más profundas** y problemas más complejos.

# %% [markdown]
# ## Recursos
#
# - [PyTorch — Learn the Basics](https://docs.pytorch.org/tutorials/beginner/basics/intro.html)
# - [Scikit-learn — Wine Dataset](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_wine.html)
