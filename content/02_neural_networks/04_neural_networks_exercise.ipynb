# %% [markdown]
# # Ejercicio Integrador — Redes Neuronales
#
# En esta actividad aplicarás **todo lo aprendido hasta ahora**:
#
# - features;
# - weights;
# - bias;
# - neurona artificial;
# - combinación lineal;
# - funciones de activación;
# - hidden layers;
# - output layers;
# - dimensiones de matrices;
# - número de parámetros;
# - forward pass.
#
# Trabajaremos con un problema científico **simulado con fines educativos**.
#
# > Imaginemos que queremos clasificar señales astronómicas en dos categorías a partir de tres mediciones.
#
# Las features serán:
#
# - `brightness` — brillo relativo;
# - `color_index` — índice de color;
# - `variability` — variabilidad de la señal.
#
# La salida será:
#
# ```text
# 0 → objeto estable
# 1 → objeto variable
# ```
#
# ---
#
# ## Cómo trabajar este ejercicio
#
# Para cada sección:
#
# 1. intenta resolverla primero;
# 2. abre **Pista** solamente si la necesitas;
# 3. abre **Solución** después de intentarlo.
#
# La meta no es memorizar código.
#
# La meta es entender **qué está ocurriendo dentro de la red**.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Parte 1 — Las entradas de la red
#
# Supongamos que observamos un objeto astronómico y obtenemos:
#
# \[
# x_1 = 0.80
# \]
#
# \[
# x_2 = 0.35
# \]
#
# \[
# x_3 = 0.60
# \]
#
# Estas mediciones ya han sido normalizadas.
#
# Construye el vector:
#
# \[
# \mathbf{x} =
# \begin{bmatrix}
# x_1\\
# x_2\\
# x_3
# \end{bmatrix}
# \]
#
# ### Tu código

# %%
# Escribe tu solución aquí

# %% [markdown]
# <details>
# <summary><strong>Pista</strong></summary>
#
# Usa:
#
# ```python
# np.array([...])
# ```
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# x = np.array([0.80, 0.35, 0.60])
# print(x)
# ```
#
# </details>

# %% [markdown]
# ## Pregunta conceptual
#
# ¿Cuántas **features** tiene este sample?
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# Tiene **3 features**.
#
# Por lo tanto, cualquier primera capa que reciba este sample debe aceptar **3 inputs**.
#
# </details>

# %% [markdown]
# # Parte 2 — Una neurona artificial
#
# Una neurona utiliza:
#
# \[z=\mathbf{w}\cdot\mathbf{x}+b.\]
#
# Supongamos:
#
# \[\mathbf{w}= \begin{bmatrix}
# 0.50\\
# -0.80\\
# 1.20
# \end{bmatrix}\]
#
# y:
#
# \[b=-0.10.\]
#
# Calcula \(z\).
#
# ### Tu código

# %%
# Define w y b y calcula z

# %% [markdown]
# <details>
# <summary><strong>Pista</strong></summary>
#
# Puedes usar:
#
# ```python
# np.dot(w, x) + b
# ```
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# x = np.array([0.80, 0.35, 0.60])
# w = np.array([0.50, -0.80, 1.20])
# b = -0.10
#
# z = np.dot(w, x) + b
#
# print("z =", z)
# ```
#
# </details>

# %% [markdown]
# ## Interpreta los weights
#
# Observa:
#
# \[
# w_1=0.50,\qquad
# w_2=-0.80,\qquad
# w_3=1.20.
# \]
#
# ### Pregunta
#
# ¿Cuál feature tiene la contribución positiva más fuerte?
#
# ¿Cuál tiene una contribución negativa?
#
# <details>
# <summary><strong>Pista</strong></summary>
#
# Mira el signo y magnitud de cada weight.
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# - `variability` tiene el weight positivo más grande: \(1.20\).
# - `color_index` tiene un weight negativo: \(-0.80\).
#
# Eso significa que, para estos parámetros particulares, aumentar `variability` tiende a aumentar \(z\), mientras que aumentar `color_index` tiende a reducirlo.
#
# </details>

# %% [markdown]
# # Parte 3 — El papel del bias
#
# Mantén los mismos valores de `x` y `w`.
#
# Calcula \(z\) para:
#
# ```python
# b = -1.0
# b =  0.0
# b =  1.0
# ```
#
# ### Tu código

# %%
# Prueba varios valores de bias

# %% [markdown]
# <details>
# <summary><strong>Pista</strong></summary>
#
# Puedes usar un `for`:
#
# ```python
# for b in [...]:
#     ...
# ```
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# for b in [-1.0, 0.0, 1.0]:
#     z = np.dot(w, x) + b
#     print(f"b = {b:4.1f}  ->  z = {z:.3f}")
# ```
#
# El bias desplaza la salida de la neurona sin cambiar las features.
#
# </details>

# %% [markdown]
# # Parte 4 — Funciones de activación
#
# Definiremos:
#
# \[
# \mathrm{ReLU}(z)=\max(0,z)
# \]
#
# y:
#
# \[
# \sigma(z)=\frac{1}{1+e^{-z}}.
# \]
#
# Completa ambas funciones.

# %%
def relu(z):
    # completa
    pass

def sigmoid(z):
    # completa
    pass

# %% [markdown]
# <details>
# <summary><strong>Pista</strong></summary>
#
# Para ReLU:
#
# ```python
# np.maximum(0, z)
# ```
#
# Para Sigmoid necesitas:
#
# ```python
# np.exp(...)
# ```
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# def relu(z):
#     return np.maximum(0, z)
#
# def sigmoid(z):
#     return 1 / (1 + np.exp(-z))
# ```
#
# </details>

# %% [markdown]
# ## Aplica ambas activaciones
#
# Usa el valor de \(z\) obtenido con:
#
# ```python
# b = -0.10
# ```
#
# y calcula:
#
# ```python
# relu(z)
# sigmoid(z)
# ```
#
# ### Tu código

# %%
# Tu código aquí

# %% [markdown]
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# b = -0.10
# z = np.dot(w, x) + b
#
# print("z =", z)
# print("ReLU(z) =", relu(z))
# print("Sigmoid(z) =", sigmoid(z))
# ```
#
# </details>

# %% [markdown]
# ## Pregunta conceptual
#
# Si queremos una salida entre 0 y 1 para una clasificación binaria, ¿cuál de estas dos activaciones parece más natural para la **salida final**?
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# **Sigmoid**, porque transforma cualquier valor real a un número entre 0 y 1.
#
# ReLU se utiliza con mucha frecuencia en **hidden layers**.
#
# </details>

# %% [markdown]
# # Parte 5 — De una neurona a una capa
#
# Ahora construiremos una hidden layer con:
#
# ```text
# 3 inputs → 4 neuronas
# ```
#
# Eso significa:
#
# \[
# W_1\in\mathbb{R}^{4\times3}.
# \]
#
# y:
#
# \[
# b_1\in\mathbb{R}^{4}.
# \]
#
# Usaremos los siguientes parámetros:

# %%
W1 = np.array([
    [ 0.50, -0.20,  0.80],
    [-0.30,  0.90,  0.10],
    [ 0.70,  0.40, -0.50],
    [ 0.20, -0.60,  1.00]
])

b1 = np.array([0.10, -0.20, 0.05, 0.30])

print("W1.shape =", W1.shape)
print("b1.shape =", b1.shape)

# %% [markdown]
# ### Pregunta
#
# ¿Por qué `W1.shape` es `(4, 3)`?
#
# <details>
# <summary><strong>Pista</strong></summary>
#
# Piensa:
#
# ```text
# 4 neuronas
# 3 inputs por neurona
# ```
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# Cada una de las 4 neuronas necesita un weight para cada una de las 3 features.
#
# Por eso tenemos:
#
# \[
# 4\times3=12
# \]
#
# weights.
#
# </details>

# %% [markdown]
# ## Calcula el forward pass de la hidden layer
#
# Calcula:
#
# \[
# \mathbf{z}_1=W_1\mathbf{x}+b_1
# \]
#
# y luego:
#
# \[
# \mathbf{a}_1=\mathrm{ReLU}(\mathbf{z}_1).
# \]
#
# ### Tu código

# %%
# z1 = ...
# a1 = ...

# %% [markdown]
# <details>
# <summary><strong>Pista</strong></summary>
#
# Usa:
#
# ```python
# W1 @ x + b1
# ```
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# z1 = W1 @ x + b1
# a1 = relu(z1)
#
# print("z1 =", z1)
# print("a1 =", a1)
# ```
#
# </details>

# %% [markdown]
# # Parte 6 — Output Layer
#
# Queremos una clasificación binaria, así que nuestra output layer tendrá **1 neurona**.
#
# La arquitectura completa será:
#
# ```text
# 3 → 4 → 1
# ```
#
# Usaremos:

# %%
W2 = np.array([[0.60, -0.40, 0.90, 0.30]])
b2 = np.array([-0.20])

print("W2.shape =", W2.shape)
print("b2.shape =", b2.shape)

# %% [markdown]
# Calcula:
#
# \[
# z_2=W_2a_1+b_2
# \]
#
# y luego:
#
# \[
# \hat{y}=\sigma(z_2).
# \]
#
# ### Tu código

# %%
# z2 = ...
# y_hat = ...

# %% [markdown]
# <details>
# <summary><strong>Pista</strong></summary>
#
# Primero:
#
# ```python
# z2 = W2 @ a1 + b2
# ```
#
# Después aplica `sigmoid`.
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# z2 = W2 @ a1 + b2
# y_hat = sigmoid(z2)
#
# print("z2 =", z2)
# print("y_hat =", y_hat)
# ```
#
# </details>

# %% [markdown]
# ## Interpretación
#
# Supongamos que usamos:
#
# ```text
# y_hat > 0.5 → objeto variable
# y_hat ≤ 0.5 → objeto estable
# ```
#
# Escribe una línea de código que produzca la clase final.
#
# ### Tu código

# %%
# prediction = ...

# %% [markdown]
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# prediction = 1 if y_hat.item() > 0.5 else 0
# print(prediction)
# ```
#
# </details>

# %% [markdown]
# # Parte 7 — Cuenta los parámetros
#
# Nuestra red es:
#
# ```text
# 3 → 4 → 1
# ```
#
# ### Primera capa
#
# ¿Cuántos parámetros tiene?
#
# Recuerda:
#
# \[
# n_{\text{params}}
# =
# n_{\text{inputs}}n_{\text{outputs}}
# +
# n_{\text{outputs}}.
# \]
#
# ### Segunda capa
#
# ¿Cuántos parámetros tiene?
#
# ### Total
#
# ¿Cuántos parámetros entrenables tiene toda la red?

# %% [markdown]
# <details>
# <summary><strong>Pista</strong></summary>
#
# Primera capa:
#
# \[
# 3\times4+4
# \]
#
# Segunda capa:
#
# \[
# 4\times1+1
# \]
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# Primera capa:
#
# \[
# 3\times4+4=16
# \]
#
# Segunda capa:
#
# \[
# 4\times1+1=5
# \]
#
# Total:
#
# \[
# 16+5=21.
# \]
#
# La red tiene **21 parámetros entrenables**.
#
# </details>

# %% [markdown]
# # Parte 8 — Construye el forward pass completo
#
# Ahora escribe una función:
#
# ```python
# def forward(x):
#     ...
#     return y_hat
# ```
#
# que implemente toda la red:
#
# ```text
# x
# ↓
# Linear 3→4
# ↓
# ReLU
# ↓
# Linear 4→1
# ↓
# Sigmoid
# ↓
# prediction
# ```
#
# ### Tu código

# %%
def forward(x):
    # completa la red aquí
    pass

# %% [markdown]
# <details>
# <summary><strong>Pista</strong></summary>
#
# Necesitas cuatro pasos:
#
# ```python
# z1 = ...
# a1 = ...
# z2 = ...
# y_hat = ...
# ```
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# def forward(x):
#     z1 = W1 @ x + b1
#     a1 = relu(z1)
#
#     z2 = W2 @ a1 + b2
#     y_hat = sigmoid(z2)
#
#     return y_hat
# ```
#
# </details>

# %% [markdown]
# Prueba tu función:

# %%
# Si ya completaste forward, ejecuta:

# print(forward(x))

# %% [markdown]
# # Parte 9 — ¿Qué ocurre cuando cambian las features?
#
# Prueba estas tres observaciones:

# %%
samples = {
    "Objeto A": np.array([0.80, 0.35, 0.60]),
    "Objeto B": np.array([0.30, 0.80, 0.10]),
    "Objeto C": np.array([0.65, 0.20, 0.90]),
}

# Usa tu función forward para obtener una salida para cada objeto.

# %% [markdown]
# ### Tu tarea
#
# Imprime:
#
# ```text
# nombre del objeto → salida de la red
# ```
#
# <details>
# <summary><strong>Pista</strong></summary>
#
# Usa:
#
# ```python
# for name, sample in samples.items():
#     ...
# ```
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```python
# for name, sample in samples.items():
#     output = forward(sample)
#     print(name, "->", output.item())
# ```
#
# </details>

# %% [markdown]
# # Parte 10 — Reto de arquitectura
#
# Ahora imagina un problema científico con:
#
# - 5 features de entrada;
# - una primera hidden layer de 8 neuronas;
# - una segunda hidden layer de 4 neuronas;
# - 3 clases de salida.
#
# ### Pregunta 1
#
# Escribe la arquitectura usando flechas.
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# ```text
# 5 → 8 → 4 → 3
# ```
#
# </details>
#
# ### Pregunta 2
#
# ¿Cuántos parámetros tiene toda la red?
#
# <details>
# <summary><strong>Pista</strong></summary>
#
# Calcula capa por capa:
#
# \[
# 5\to8
# \]
#
# \[
# 8\to4
# \]
#
# \[
# 4\to3
# \]
#
# </details>
#
# <details>
# <summary><strong>Mostrar solución</strong></summary>
#
# Primera capa:
#
# \[
# 5\times8+8=48
# \]
#
# Segunda:
#
# \[
# 8\times4+4=36
# \]
#
# Tercera:
#
# \[
# 4\times3+3=15
# \]
#
# Total:
#
# \[
# 48+36+15=99
# \]
#
# parámetros.
#
# </details>

# %% [markdown]
# # Desafío final — ¿Qué aprendió realmente esta red?
#
# Hasta ahora los weights y biases fueron **dados por nosotros**.
#
# Pero una red neuronal real debe aprenderlos.
#
# Reflexiona:
#
# > Si la predicción es incorrecta, ¿qué valores deberían cambiar para mejorar el resultado?
#
# <details>
# <summary><strong>💡 Pista</strong></summary>
#
# Piensa en cuáles cantidades hemos llamado **parámetros entrenables**.
#
# </details>
#
# <details>
# <summary><strong>✅ Mostrar solución</strong></summary>
#
# Los valores que deben ajustarse son principalmente:
#
# - los **weights**;
# - los **biases**.
#
# Durante el entrenamiento, la red modifica estos parámetros para reducir su error.
#
# Esto nos lleva directamente al próximo módulo:
#
# ```text
# Forward Pass
#     ↓
# Loss
#     ↓
# Gradient Descent
#     ↓
# Backpropagation
#     ↓
# Update Parameters
# ```
#
# </details>

# %% [markdown]
# # Conexión con el salón de clases
#
# Este mismo ejercicio puede adaptarse a diferentes preguntas científicas:
#
# | Área | Features | Salida |
# |---|---|---|
# | Astronomía | brillo, color, variabilidad | tipo de objeto |
# | Meteorología | temperatura, humedad, presión | condición atmosférica |
# | Botánica | largo, ancho, área de hoja | especie |
# | Física | energía, velocidad, posición | tipo de evento |
# | Ecología | temperatura, lluvia, suelo | tipo de hábitat |
#
# La pregunta que queremos que los estudiantes aprendan a formular es:
#
# > **¿Qué mediciones necesita el modelo y cómo transforma esas mediciones en una decisión?**

# %% [markdown]
# # Checklist final
#
# Antes de continuar, verifica que puedes explicar:
#
# - [ ] qué es una feature;
# - [ ] qué hace un weight;
# - [ ] qué hace el bias;
# - [ ] qué calcula una neurona;
# - [ ] qué hace ReLU;
# - [ ] qué hace Sigmoid;
# - [ ] qué significa una arquitectura `3 → 4 → 1`;
# - [ ] cómo calcular el número de parámetros;
# - [ ] qué es un forward pass;
# - [ ] qué parámetros tendrá que aprender la red.
#
# Si puedes explicar estos puntos, estás listo para estudiar **cómo aprende una red neuronal**.
